# %% [markdown]
# # Forecasting Example
#
# This notebook demonstrates the forecasting pipeline using the included synthetic dataset. Run the pipeline script or follow the cells below to reproduce the results.

# %%
# If running in the notebook, load required libs
import pandas as pd
from pathlib import Path

# Load sample data
df = pd.read_csv('data/sample_sales.csv', parse_dates=['date'])
df.head()

# %% [markdown]
# Run the pipeline script to train and save outputs. In a terminal:
#
# ```
# python src/forecasting_pipeline.py --data data/sample_sales.csv --output outputs
# ```
#
# Then view outputs/forecast.png and outputs/model.joblib.
